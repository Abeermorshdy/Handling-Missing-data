# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("customer .csv" , sep = "," , encoding = 'utf-8')

# %%
housing = pd.read_csv("housing2.csv" , sep = "," , encoding = 'utf-8')

# %%
housing.head(10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0          880           129.0
# 1    -122.22     37.86                21.0         7099          1106.0
# 2    -122.24     37.85                52.0         1467           190.0
# 3    -122.25     37.85                52.0         1274           235.0
# 4    -122.25     37.85                 NaN         1627           280.0
# 5    -122.25     37.85                 NaN          919           213.0
# 6    -122.25     37.84                 NaN         2535             NaN
# 7    -122.25     37.84                 NaN         3104             NaN
# 8    -122.26     37.84                42.0         2555             NaN
# 9    -122.25     37.84                52.0         3549             NaN
#
#    population households  median_income  median_house_value ocean_proximity  \
# 0       322.0        126         8.3252              452600        NEAR BAY
# ...

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20382 non-null  float64
#  3   total_rooms         20640 non-null  int64
#  4   total_bedrooms      15758 non-null  float64
#  5   population          20596 non-null  float64
#  6   households          19335 non-null  object
#  7   median_income       17873 non-null  float64
#  8   median_house_value  20640 non-null  int64
#  9   ocean_proximity     20640 non-null  object
#  10  gender              16620 non-null  object
# dtypes: float64(6), int64(2), object(3)
# memory usage: 1.7+ MB

# %%
housing.isnull().sum()
# Out:
# longitude                0
# latitude                 0
# housing_median_age     258
# total_rooms              0
# total_bedrooms        4882
# population              44
# households            1305
# median_income         2767
# median_house_value       0
# ocean_proximity          0
# gender                4020
# dtype: int64

# %%
housing.dropna()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0          880           129.0
# 1        -122.22     37.86                21.0         7099          1106.0
# 2        -122.24     37.85                52.0         1467           190.0
# 3        -122.25     37.85                52.0         1274           235.0
# 17       -122.27     37.85                52.0         1228           293.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0         1665           374.0
# 20636    -121.21     39.49                18.0          697           150.0
# 20637    -121.22     39.43                17.0         2254           485.0
# 20638    -121.32     39.43                18.0         1860           409.0
# 20639    -121.24     39.37                16.0         2785           616.0
#
# ...

# %%
sns.heatmap(housing.isnull())
# Out:
# <AxesSubplot:>

# %%
x = housing.dropna(thresh = 10)
x
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0          880           129.0
# 1        -122.22     37.86                21.0         7099          1106.0
# 2        -122.24     37.85                52.0         1467           190.0
# 3        -122.25     37.85                52.0         1274           235.0
# 13       -122.26     37.84                52.0          696           191.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0         1665           374.0
# 20636    -121.21     39.49                18.0          697           150.0
# 20637    -121.22     39.43                17.0         2254           485.0
# 20638    -121.32     39.43                18.0         1860           409.0
# 20639    -121.24     39.37                16.0         2785           616.0
#
# ...

# %%
sns.heatmap(housing.isnull())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(x.isnull())
# Out:
# <AxesSubplot:>

# %%
x = housing.dropna(thresh = 9)
x
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0          880           129.0
# 1        -122.22     37.86                21.0         7099          1106.0
# 2        -122.24     37.85                52.0         1467           190.0
# 3        -122.25     37.85                52.0         1274           235.0
# 4        -122.25     37.85                 NaN         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0         1665           374.0
# 20636    -121.21     39.49                18.0          697           150.0
# 20637    -121.22     39.43                17.0         2254           485.0
# 20638    -121.32     39.43                18.0         1860           409.0
# 20639    -121.24     39.37                16.0         2785           616.0
#
# ...

# %%
sns.heatmap(x.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Missing Data

# %%
df = pd.read_csv("customer .csv" , sep = "," , encoding = 'utf-8')

# %% [markdown]
# ### Drop

# %%
data = df.copy()

# %%
data.isnull()
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0          False   False           True    False       False    True
# 1          False   False           True    False       False   False
# 2          False   False           True    False       False   False
# 3          False   False           True    False       False   False
# 4          False   False           True    False       False   False
# ...          ...     ...            ...      ...         ...     ...
# 7038       False   False          False    False       False   False
# 7039       False   False          False    False       False   False
# 7040       False   False          False    False       False   False
# 7041       False   False          False    False       False   False
# 7042       False   False          False    False       False   False
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# ...

# %%
data.isnull().sum()
# Out:
# customerID            0
# gender                0
# SeniorCitizen        43
# Partner               0
# Dependents            0
# tenure              147
# PhoneService          0
# MultipleLines         0
# InternetService       0
# OnlineSecurity        0
# OnlineBackup          0
# DeviceProtection      0
# TechSupport           0
# StreamingTV           0
# StreamingMovies       0
# Contract              0
# PaperlessBilling      0
# PaymentMethod         0
# MonthlyCharges        0
# TotalCharges          0
# Churn                 0
# dtype: int64

# %%
data.dropna()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 30    3841-NFECX  Female            1.0     Yes         No    71.0
# 31    4929-XIHVW    Male            1.0     Yes         No     2.0
# 47    7760-OYPDY  Female            0.0      No         No     2.0
# 48    7639-LIAYI    Male            0.0      No         No    52.0
# 49    2954-PIBKO  Female            0.0     Yes        Yes    69.0
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male            0.0     Yes        Yes    24.0
# 7039  2234-XADUH  Female            0.0     Yes        Yes    72.0
# 7040  4801-JZAZL  Female            0.0     Yes        Yes    11.0
# 7041  8361-LTMKD    Male            1.0     Yes         No     4.0
# 7042  3186-AJIEK    Male            0.0      No         No    66.0
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 30            Yes               Yes     Fiber optic            Yes  ...
# ...

# %%
data.dropna(thresh = 20)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 1     5575-GNVDE    Male            NaN      No         No    34.0
# 2     3668-QPYBK    Male            NaN      No         No     2.0
# 3     7795-CFOCW    Male            NaN      No         No    45.0
# 4     9237-HQITU  Female            NaN      No         No     2.0
# 5     9305-CDSKC  Female            NaN      No         No     8.0
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male            0.0     Yes        Yes    24.0
# 7039  2234-XADUH  Female            0.0     Yes        Yes    72.0
# 7040  4801-JZAZL  Female            0.0     Yes        Yes    11.0
# 7041  8361-LTMKD    Male            1.0     Yes         No     4.0
# 7042  3186-AJIEK    Male            0.0      No         No    66.0
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 1             Yes                No             DSL            Yes  ...
# ...

# %%
data.dropna() #inplace = True

# %%
df2 = data.dropna()

# %%
df2.shape
# Out:
# (6857, 21)

# %%
data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# customerID            0
# gender                0
# SeniorCitizen        43
# Partner               0
# Dependents            0
# tenure              147
# PhoneService          0
# MultipleLines         0
# InternetService       0
# OnlineSecurity        0
# OnlineBackup          0
# DeviceProtection      0
# TechSupport           0
# StreamingTV           0
# StreamingMovies       0
# Contract              0
# PaperlessBilling      0
# PaymentMethod         0
# MonthlyCharges        0
# TotalCharges          0
# Churn                 0
# dtype: int64

# %%
data.dropna(subset=['SeniorCitizen']) #, inplace = True
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 20    8779-QRDMV    Male            1.0      No         No     NaN
# 30    3841-NFECX  Female            1.0     Yes         No    71.0
# 31    4929-XIHVW    Male            1.0     Yes         No     2.0
# 34    3413-BMNZE    Male            1.0      No         No     NaN
# 47    7760-OYPDY  Female            0.0      No         No     2.0
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male            0.0     Yes        Yes    24.0
# 7039  2234-XADUH  Female            0.0     Yes        Yes    72.0
# 7040  4801-JZAZL  Female            0.0     Yes        Yes    11.0
# 7041  8361-LTMKD    Male            1.0     Yes         No     4.0
# 7042  3186-AJIEK    Male            0.0      No         No    66.0
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 20             No  No phone service             DSL             No  ...
# ...

# %%
df2 = data.dropna(subset=['SeniorCitizen'])

# %%
data.drop_duplicates()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female            NaN     Yes         No     NaN
# 1     5575-GNVDE    Male            NaN      No         No    34.0
# 2     3668-QPYBK    Male            NaN      No         No     2.0
# 3     7795-CFOCW    Male            NaN      No         No    45.0
# 4     9237-HQITU  Female            NaN      No         No     2.0
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male            0.0     Yes        Yes    24.0
# 7039  2234-XADUH  Female            0.0     Yes        Yes    72.0
# 7040  4801-JZAZL  Female            0.0     Yes        Yes    11.0
# 7041  8361-LTMKD    Male            1.0     Yes         No     4.0
# 7042  3186-AJIEK    Male            0.0      No         No    66.0
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
data.drop_duplicates(subset=['gender'])
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female            NaN     Yes         No     NaN           No
# 1  5575-GNVDE    Male            NaN      No         No    34.0          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
#
#       PaymentMethod MonthlyCharges  TotalCharges  Churn
# 0  Electronic check          29.85         29.85     No
# 1      Mailed check          56.95       1889.50     No
#
# [2 rows x 21 columns]

# %%
data.drop("customerID" , axis = 1) #, inplace = True
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female            NaN     Yes         No     NaN           No
# 1       Male            NaN      No         No    34.0          Yes
# 2       Male            NaN      No         No     2.0          Yes
# 3       Male            NaN      No         No    45.0           No
# 4     Female            NaN      No         No     2.0          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male            0.0     Yes        Yes    24.0          Yes
# 7039  Female            0.0     Yes        Yes    72.0          Yes
# 7040  Female            0.0     Yes        Yes    11.0           No
# 7041    Male            1.0     Yes         No     4.0          Yes
# 7042    Male            0.0      No         No    66.0          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# ...

# %%
data.drop(0)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 1     5575-GNVDE    Male            NaN      No         No    34.0
# 2     3668-QPYBK    Male            NaN      No         No     2.0
# 3     7795-CFOCW    Male            NaN      No         No    45.0
# 4     9237-HQITU  Female            NaN      No         No     2.0
# 5     9305-CDSKC  Female            NaN      No         No     8.0
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male            0.0     Yes        Yes    24.0
# 7039  2234-XADUH  Female            0.0     Yes        Yes    72.0
# 7040  4801-JZAZL  Female            0.0     Yes        Yes    11.0
# 7041  8361-LTMKD    Male            1.0     Yes         No     4.0
# 7042  3186-AJIEK    Male            0.0      No         No    66.0
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 1             Yes                No             DSL            Yes  ...
# ...

# %%
data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
data.drop(['gender', 'SeniorCitizen', 'Partner', 'Dependents'] , axis = 1)
# Out:
#       customerID  tenure PhoneService     MultipleLines InternetService  \
# 0     7590-VHVEG     NaN           No  No phone service             DSL
# 1     5575-GNVDE    34.0          Yes                No             DSL
# 2     3668-QPYBK     2.0          Yes                No             DSL
# 3     7795-CFOCW    45.0           No  No phone service             DSL
# 4     9237-HQITU     2.0          Yes                No     Fiber optic
# ...          ...     ...          ...               ...             ...
# 7038  6840-RESVB    24.0          Yes               Yes             DSL
# 7039  2234-XADUH    72.0          Yes               Yes     Fiber optic
# 7040  4801-JZAZL    11.0           No  No phone service             DSL
# 7041  8361-LTMKD     4.0          Yes               Yes     Fiber optic
# 7042  3186-AJIEK    66.0          Yes                No     Fiber optic
#
#      OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV  \
# ...

# %% [markdown]
#  ### Fill Missing data

# %%
data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
data['SeniorCitizen'].value_counts()
# Out:
# 0.0    5858
# 1.0    1142
# Name: SeniorCitizen, dtype: int64

# %%
data['SeniorCitizen'].describe()
# Out:
# count    7000.000000
# mean        0.163143
# std         0.369522
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: SeniorCitizen, dtype: float64

# %%
data['SeniorCitizen'] = data['SeniorCitizen'].fillna("Doaa")

# %%
data['SeniorCitizen'].fillna("Doaa" , inplace = True)

# %%
data
# Out:
#       customerID  gender SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female          Doaa     Yes         No     NaN
# 1     5575-GNVDE    Male          Doaa      No         No    34.0
# 2     3668-QPYBK    Male          Doaa      No         No     2.0
# 3     7795-CFOCW    Male          Doaa      No         No    45.0
# 4     9237-HQITU  Female          Doaa      No         No     2.0
# ...          ...     ...           ...     ...        ...     ...
# 7038  6840-RESVB    Male           0.0     Yes        Yes    24.0
# 7039  2234-XADUH  Female           0.0     Yes        Yes    72.0
# 7040  4801-JZAZL  Female           0.0     Yes        Yes    11.0
# 7041  8361-LTMKD    Male           1.0     Yes         No     4.0
# 7042  3186-AJIEK    Male           0.0      No         No    66.0
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
data['SeniorCitizen'].value_counts()
# Out:
# 0.0     5858
# 1.0     1142
# Doaa      43
# Name: SeniorCitizen, dtype: int64

# %%
data = df.copy()

# %%
data.isnull().sum()
# Out:
# customerID            0
# gender                0
# SeniorCitizen        43
# Partner               0
# Dependents            0
# tenure              147
# PhoneService          0
# MultipleLines         0
# InternetService       0
# OnlineSecurity        0
# OnlineBackup          0
# DeviceProtection      0
# TechSupport           0
# StreamingTV           0
# StreamingMovies       0
# Contract              0
# PaperlessBilling      0
# PaymentMethod         0
# MonthlyCharges        0
# TotalCharges          0
# Churn                 0
# dtype: int64

# %%
data['tenure'].value_counts()
# Out:
# 1.0     477
# 72.0    362
# 2.0     238
# 3.0     200
# 4.0     176
#        ...
# 38.0     59
# 28.0     57
# 39.0     56
# 44.0     51
# 36.0     50
# Name: tenure, Length: 72, dtype: int64

# %%
data['tenure'].mean()
# Out:
# 33.04147331786543

# %%
ten_mean = data['tenure'].mean()

# %%
data['tenure'] = data['tenure'].fillna(ten_mean)

# %%
data['tenure']
# Out:
# 0       33.041473
# 1       34.000000
# 2        2.000000
# 3       45.000000
# 4        2.000000
#           ...
# 7038    24.000000
# 7039    72.000000
# 7040    11.000000
# 7041     4.000000
# 7042    66.000000
# Name: tenure, Length: 7043, dtype: float64

# %%
data = df.copy()

# %%
data['tenure'] = data['tenure'].fillna(method= "ffill")

# %%
data
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female            NaN     Yes         No     NaN
# 1     5575-GNVDE    Male            NaN      No         No    34.0
# 2     3668-QPYBK    Male            NaN      No         No     2.0
# 3     7795-CFOCW    Male            NaN      No         No    45.0
# 4     9237-HQITU  Female            NaN      No         No     2.0
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male            0.0     Yes        Yes    24.0
# 7039  2234-XADUH  Female            0.0     Yes        Yes    72.0
# 7040  4801-JZAZL  Female            0.0     Yes        Yes    11.0
# 7041  8361-LTMKD    Male            1.0     Yes         No     4.0
# 7042  3186-AJIEK    Male            0.0      No         No    66.0
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
data = df.copy()

# %%
data['tenure'] = data['tenure'].fillna(method= "bfill")

# %%
data
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female            NaN     Yes         No    34.0
# 1     5575-GNVDE    Male            NaN      No         No    34.0
# 2     3668-QPYBK    Male            NaN      No         No     2.0
# 3     7795-CFOCW    Male            NaN      No         No    45.0
# 4     9237-HQITU  Female            NaN      No         No     2.0
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male            0.0     Yes        Yes    24.0
# 7039  2234-XADUH  Female            0.0     Yes        Yes    72.0
# 7040  4801-JZAZL  Female            0.0     Yes        Yes    11.0
# 7041  8361-LTMKD    Male            1.0     Yes         No     4.0
# 7042  3186-AJIEK    Male            0.0      No         No    66.0
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
housing['gender'].value_counts()
# Out:
# female    8673
# male      7947
# Name: gender, dtype: int64

# %%
housing.isnull().sum()
# Out:
# longitude                0
# latitude                 0
# housing_median_age     258
# total_rooms              0
# total_bedrooms        4882
# population              44
# households            1305
# median_income         2767
# median_house_value       0
# ocean_proximity          0
# gender                4020
# dtype: int64

# %%
sns.countplot(housing['gender'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
fill_list = ['female' , 'male']
housing['gender'] = housing['gender'].fillna(pd.Series(np.random.choice(fill_list , size = len(housing.index))))

# %%
housing['gender'].value_counts()
# Out:
# female    10715
# male       9925
# Name: gender, dtype: int64

# %%
sns.countplot(housing['gender'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
housing
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0          880           129.0
# 1        -122.22     37.86                21.0         7099          1106.0
# 2        -122.24     37.85                52.0         1467           190.0
# 3        -122.25     37.85                52.0         1274           235.0
# 4        -122.25     37.85                 NaN         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0         1665           374.0
# 20636    -121.21     39.49                18.0          697           150.0
# 20637    -121.22     39.43                17.0         2254           485.0
# 20638    -121.32     39.43                18.0         1860           409.0
# 20639    -121.24     39.37                16.0         2785           616.0
#
# ...

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20382 non-null  float64
#  3   total_rooms         20640 non-null  int64
#  4   total_bedrooms      15758 non-null  float64
#  5   population          20596 non-null  float64
#  6   households          19335 non-null  object
#  7   median_income       17873 non-null  float64
#  8   median_house_value  20640 non-null  int64
#  9   ocean_proximity     20640 non-null  object
#  10  gender              20640 non-null  object
# dtypes: float64(6), int64(2), object(3)
# memory usage: 1.7+ MB

# %%
housing['households'].value_counts()
# Out:
# no      3080
# 282       47
# 375       46
# 380       45
# 306       45
#         ...
# 1649       1
# 1879       1
# 1050       1
# 1119       1
# 1843       1
# Name: households, Length: 1703, dtype: int64

# %%
#housing['household'] = housing['household'].replace('no' , np.nan)

# %%
#data = data.replace['-1' , -1]

# %%
data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
data['SeniorCitizen'].mode()[0]
# Out:
# 0    0.0
# Name: SeniorCitizen, dtype: float64

# %%
fill = {'tenure': data['tenure'].mean() , "SeniorCitizen": data['SeniorCitizen'].mode()[0]}
data.fillna(fill , inplace = True)

# %%
data.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
data['MonthlyCharges'].describe()
# Out:
# count    7043.000000
# mean       64.761692
# std        30.090047
# min        18.250000
# 25%        35.500000
# 50%        70.350000
# 75%        89.850000
# max       118.750000
# Name: MonthlyCharges, dtype: float64

# %%
inte = [18 , 40 , 80 , 100 ,120]
cat = [1,2,3,4]
data['offer_month'] = pd.cut(data['MonthlyCharges'] , bins = inte , labels = cat)

# %%
data
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female            0.0     Yes         No    34.0
# 1     5575-GNVDE    Male            0.0      No         No    34.0
# 2     3668-QPYBK    Male            0.0      No         No     2.0
# 3     7795-CFOCW    Male            0.0      No         No    45.0
# 4     9237-HQITU  Female            0.0      No         No     2.0
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male            0.0     Yes        Yes    24.0
# 7039  2234-XADUH  Female            0.0     Yes        Yes    72.0
# 7040  4801-JZAZL  Female            0.0     Yes        Yes    11.0
# 7041  8361-LTMKD    Male            1.0     Yes         No     4.0
# 7042  3186-AJIEK    Male            0.0      No         No    66.0
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
data.offer_month.value_counts()
# Out:
# 2    2539
# 1    1838
# 3    1764
# 4     902
# Name: offer_month, dtype: int64

# %%
data['TotalCharges'].describe()
# Out:
# count    7043.000000
# mean     2283.300440
# std      2265.000258
# min        18.800000
# 25%       402.225000
# 50%      1400.550000
# 75%      3786.600000
# max      8684.800000
# Name: TotalCharges, dtype: float64

# %%
inter = pd.interval_range(start= 18 , freq= 500 , end=8685)
data['offer_total'] = pd.cut(data['TotalCharges'] , bins = inter , labels = [])

# %%
data
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female            0.0     Yes         No    34.0
# 1     5575-GNVDE    Male            0.0      No         No    34.0
# 2     3668-QPYBK    Male            0.0      No         No     2.0
# 3     7795-CFOCW    Male            0.0      No         No    45.0
# 4     9237-HQITU  Female            0.0      No         No     2.0
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male            0.0     Yes        Yes    24.0
# 7039  2234-XADUH  Female            0.0     Yes        Yes    72.0
# 7040  4801-JZAZL  Female            0.0     Yes        Yes    11.0
# 7041  8361-LTMKD    Male            1.0     Yes         No     4.0
# 7042  3186-AJIEK    Male            0.0      No         No    66.0
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
data['offer_total'].value_counts()
# Out:
# (18, 518]       2032
# (518, 1018]      887
# (1018, 1518]     767
# (1518, 2018]     506
# (2018, 2518]     365
# (2518, 3018]     296
# (3018, 3518]     289
# (3518, 4018]     266
# (4518, 5018]     261
# (4018, 4518]     249
# (5518, 6018]     237
# (5018, 5518]     203
# (6018, 6518]     193
# (6518, 7018]     170
# (7018, 7518]     133
# (7518, 8018]     115
# (8018, 8518]      66
# Name: offer_total, dtype: int64

# %%
data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn',
#        'offer_month', 'offer_total'],
#       dtype='object')

# %%
df = data[[ 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
       'tenure', 'PaymentMethod','MonthlyCharges', 'TotalCharges', 'Churn']]

# %%
df
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure  \
# 0     Female            0.0     Yes         No    34.0
# 1       Male            0.0      No         No    34.0
# 2       Male            0.0      No         No     2.0
# 3       Male            0.0      No         No    45.0
# 4     Female            0.0      No         No     2.0
# ...      ...            ...     ...        ...     ...
# 7038    Male            0.0     Yes        Yes    24.0
# 7039  Female            0.0     Yes        Yes    72.0
# 7040  Female            0.0     Yes        Yes    11.0
# 7041    Male            1.0     Yes         No     4.0
# 7042    Male            0.0      No         No    66.0
#
#                   PaymentMethod  MonthlyCharges  TotalCharges Churn
# 0              Electronic check           29.85         29.85    No
# 1                  Mailed check           56.95       1889.50    No
# 2                  Mailed check           53.85        108.15   Yes
# ...

# %%
#df.replace("Yes" , 1 , inplace = True)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
gender_le = LabelEncoder()
Churn_le = LabelEncoder()
PaymentMethod_le = LabelEncoder()

# %%
df['gender'] = gender_le.fit_transform(df['gender'])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9656\1557486449.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['gender'] = gender_le.fit_transform(df['gender'])

# %%
df
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure  \
# 0          0            0.0     Yes         No    34.0
# 1          1            0.0      No         No    34.0
# 2          1            0.0      No         No     2.0
# 3          1            0.0      No         No    45.0
# 4          0            0.0      No         No     2.0
# ...      ...            ...     ...        ...     ...
# 7038       1            0.0     Yes        Yes    24.0
# 7039       0            0.0     Yes        Yes    72.0
# 7040       0            0.0     Yes        Yes    11.0
# 7041       1            1.0     Yes         No     4.0
# 7042       1            0.0      No         No    66.0
#
#                   PaymentMethod  MonthlyCharges  TotalCharges Churn
# 0              Electronic check           29.85         29.85    No
# 1                  Mailed check           56.95       1889.50    No
# 2                  Mailed check           53.85        108.15   Yes
# ...

# %%
gender_le.classes_
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df['PaymentMethod'].value_counts()
# Out:
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: PaymentMethod, dtype: int64

# %%
df['PaymentMethod'] = PaymentMethod_le.fit_transform(df['PaymentMethod'])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9656\12140040.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['PaymentMethod'] = PaymentMethod_le.fit_transform(df['PaymentMethod'])

# %%
df
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure  PaymentMethod  \
# 0          0            0.0     Yes         No    34.0              2
# 1          1            0.0      No         No    34.0              3
# 2          1            0.0      No         No     2.0              3
# 3          1            0.0      No         No    45.0              0
# 4          0            0.0      No         No     2.0              2
# ...      ...            ...     ...        ...     ...            ...
# 7038       1            0.0     Yes        Yes    24.0              3
# 7039       0            0.0     Yes        Yes    72.0              1
# 7040       0            0.0     Yes        Yes    11.0              2
# 7041       1            1.0     Yes         No     4.0              3
# 7042       1            0.0      No         No    66.0              0
#
#       MonthlyCharges  TotalCharges Churn
# 0              29.85         29.85    No
# 1              56.95       1889.50    No
# ...

# %%
PaymentMethod_le.classes_
# Out:
# array(['Bank transfer (automatic)', 'Credit card (automatic)',
#        'Electronic check', 'Mailed check'], dtype=object)

# %%
df['Churn'] = Churn_le.fit_transform(df['Churn'])
df['Partner'] = Churn_le.fit_transform(df['Partner'])
df['Dependents'] = Churn_le.fit_transform(df['Dependents'])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9656\2674946014.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Churn'] = Churn_le.fit_transform(df['Churn'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9656\2674946014.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Partner'] = Churn_le.fit_transform(df['Partner'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9656\2674946014.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PaymentMethod  \
# 0          0            0.0        1           0    34.0              2
# 1          1            0.0        0           0    34.0              3
# 2          1            0.0        0           0     2.0              3
# 3          1            0.0        0           0    45.0              0
# 4          0            0.0        0           0     2.0              2
# ...      ...            ...      ...         ...     ...            ...
# 7038       1            0.0        1           1    24.0              3
# 7039       0            0.0        1           1    72.0              1
# 7040       0            0.0        1           1    11.0              2
# 7041       1            1.0        1           0     4.0              3
# 7042       1            0.0        0           0    66.0              0
#
#       MonthlyCharges  TotalCharges  Churn
# 0              29.85         29.85      0
# ...

# %%
x = df.drop("Churn" , axis = 1).values
y = df["Churn"].values

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train , y_test = train_test_split(x,y, test_size=0.25 , random_state=42)

# %%
x_train.shape
# Out:
# (5282, 8)

# %%
x_test.shape
# Out:
# (1761, 8)
